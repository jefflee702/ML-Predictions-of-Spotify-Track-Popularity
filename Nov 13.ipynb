# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('drive/MyDrive/Github/ecs-171-project/dataset.csv')
df = df.sample(n= 80000, random_state=21)
df_rem = df.drop(columns=['Unnamed: 0', 'track_id','track_name','explicit'])

# %%
df['track_genre'].unique()
# Out:
# array(['trance', 'world-music', 'house', 'drum-and-bass', 'techno',
#        'goth', 'disco', 'ambient', 'bluegrass', 'gospel', 'comedy',
#        'pop-film', 'party', 'psych-rock', 'turkish', 'swedish',
#        'classical', 'electro', 'afrobeat', 'mandopop', 'show-tunes',
#        'country', 'progressive-house', 'singer-songwriter', 'metalcore',
#        'dubstep', 'idm', 'acoustic', 'hardcore', 'latino', 'french',
#        'tango', 'garage', 'reggaeton', 'indie', 'new-age', 'honky-tonk',
#        'british', 'alternative', 'grunge', 'club', 'romance',
#        'songwriter', 'breakbeat', 'rock', 'guitar', 'alt-rock',
#        'black-metal', 'brazil', 'detroit-techno', 'hip-hop', 'pop',
#        'soul', 'hard-rock', 'jazz', 'r-n-b', 'cantopop', 'latin', 'mpb',
#        'indian', 'hardstyle', 'anime', 'children', 'groove', 'sertanejo',
#        'piano', 'j-idol', 'edm', 'happy', 'rockabilly', 'chicago-house',
#        'k-pop', 'synth-pop', 'dub', 'funk', 'j-rock', 'iranian', 'punk',
# ...

# %%
df_rem = df_rem.loc[df_rem['track_genre'] == 'reggaeton']
df['popularity'].unique()
# Out:
# array([ 27,  37,   0,  16,  48,  23,  33,  28,  38,  66,  24,  49,  47,
#         39,  34,  40,  69,  36,  55,  22,  29,  44,  85,  75,  42,  26,
#         31,  21,  80,  64,  20,  14,  53,  10,  43,   1,  60,  52,   4,
#         18,  46,   5,  71,  35,  41,  67,  54,  57,  45,  50,  70,  19,
#         79,  65,  11,  17,   8,  51,  30,  59,  32,  58,  62,  61,   3,
#         73,  74,  68,  56,   9,  12,  89,   2,  13,   6,  25,  63,  15,
#         90,  77,  76,   7,  78,  83,  88,  72,  82,  86,  81,  96,  97,
#         87,  84,  95,  94,  93,  92,  98,  91, 100])

# %%
df_rem
# Out:
#                                  artists               album_name  popularity  \
# 89823                                 MJ     Tor Monta Sudhu Chai           0
# 89415                  J Balvin;Skrillex                     JOSE          70
# 89846                         Jairo Vera                 Otra Vez          44
# 89776                       Daddy Yankee   Barrio Fino En Directo          74
# 89904  IAmChino;Pitbull;Yandel;El Chacal               Ay Mi Dios          71
# ...                                  ...                      ...         ...
# 89265                   Jhayco;Bad Bunny  Última Misión Reggaeton           0
# 89435                        Danny Ocean           Tropical Vibes           0
# 89551                    CNCO;Little Mix                     CNCO          66
# 89090                           J Balvin  Perreo Tenebroso Vol. 5           0
# 89787                              Dvice            Vamos Hacerlo          45
#
# ...

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()

#label encoding albums
df_rem['album_name'].unique()
df_rem['album_name'] = label_encoder.fit_transform(df_rem['album_name'])

# %%
# label encoding the generes
df_rem['track_genre'].unique()
df_rem['track_genre'] = label_encoder.fit_transform(df_rem['track_genre'])
#spiltting the a row with multiple artite=s into multiple rows

df_rem = (df_rem.set_index(['album_name', 'popularity', 'duration_ms', 'danceability', 'energy',
       'key', 'loudness', 'mode', 'speechiness', 'acousticness',
       'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature',
       'track_genre'])
   .apply(lambda x: x.str.split(';').explode())
   .reset_index())

# %%
# label encoding the generes
df_rem['artists'].unique().size
6533
df_rem['artists'] = label_encoder.fit_transform(df_rem['artists'])
df_rem.shape
(11023, 17)
df_rem
# Out:
#       album_name  popularity  duration_ms  danceability  energy  key  \
# 0            246           0       168892         0.702   0.969    6
# 1            111          70       130666         0.924   0.723    8
# 2            111          70       130666         0.924   0.723    8
# 3            174          44       135000         0.812   0.379    8
# 4             19          74       188626         0.696   0.858    9
# ...          ...         ...          ...           ...     ...  ...
# 1407         249           0       205714         0.743   0.804    1
# 1408          28          66       188800         0.534   0.911    4
# 1409          28          66       188800         0.534   0.911    4
# 1410         195           0       200666         0.881   0.696   11
# 1411         258          45       209972         0.685   0.709    7
#
#       loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
modified_df = df_rem.drop(columns = ['artists', 'track_genre', 'album_name', 'popularity'])
df_norm = pd.DataFrame(scaler.fit_transform(modified_df), columns = modified_df.columns)
df_norm['artists'] = df_rem['artists']
df_norm['track_genre'] = df_rem['track_genre']
df_norm['album_name'] = df_rem['album_name']
df_norm['popularity'] = df_rem['popularity']/25
df_norm.popularity=df_norm.popularity.astype(int)
df_norm_rounded = df_norm.round(2)
df_norm['popularity'].unique()
# Out:
# array([0, 2, 1, 3])

# %%
df_norm.describe()
# Out:
#        duration_ms  danceability       energy          key     loudness  \
# count  1412.000000   1412.000000  1412.000000  1412.000000  1412.000000
# mean      0.092582      0.579870     0.622705     0.507790     0.689664
# std       0.053714      0.182240     0.177459     0.324560     0.132558
# min       0.000000      0.000000     0.000000     0.000000     0.000000
# 25%       0.068437      0.462656     0.507438     0.181818     0.625621
# 50%       0.086706      0.594398     0.636364     0.545455     0.709076
# 75%       0.106202      0.707469     0.764463     0.818182     0.779524
# max       1.000000      1.000000     1.000000     1.000000     1.000000
#
#               mode  speechiness  acousticness  instrumentalness     liveness  \
# count  1412.000000  1412.000000   1412.000000       1412.000000  1412.000000
# mean      0.508499     0.187486      0.184492          0.009252     0.172984
# std       0.500105     0.182421      0.169875          0.069992     0.143556
# ...

# %%
corr = df_norm.corr()
fig, ax = plt.subplots(figsize=(14, 14))
_ = sns.heatmap(corr, vmin=-1, vmax=1, center=0, annot=True, fmt='.2',cmap= 'coolwarm')

# %%
_=sns.pairplot(data=df_norm)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-98a129ebf60b> in <module>
# ----> 1 _=sns.pairplot(data=df_norm)
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2096     grid = PairGrid(data, vars=vars, x_vars=x_vars, y_vars=y_vars, hue=hue,
#    2097                     hue_order=hue_order, palette=palette, corner=corner,
# -> 2098                     height=height, aspect=aspect, dropna=dropna, **grid_kws)
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df_norm.drop(['popularity'], axis=1), df_norm.popularity, test_size=0.2, random_state=1)
print(X_test.shape)
print(X_train.shape)
print(y_test.shape)
print(y_train.shape)
# Out:
# (283, 16)
# (1129, 16)
# (283,)
# (1129,)

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
def PolReg(deg):
    polynomial_features= PolynomialFeatures(degree=deg,include_bias=False)
    x_poly_train = polynomial_features.fit_transform(X_train)
    
    x_poly_test = polynomial_features.fit_transform(X_test)
    model = LinearRegression()
    model.fit(x_poly_train, y_train)
    yhat_train_pred = model.predict(x_poly_train)
    yhat_test_pred = model.predict(x_poly_test)
    mse = mean_squared_error(y_test,yhat_test_pred)
    print("Degree", deg,"Testing MSE :",mse)
    mse = mean_squared_error(y_train,yhat_train_pred)
    print("Degree", deg,"Training MSE :",mse)
    # plt.scatter(x, y, s=10)
    # plt.plot(x, model.predict(polynomial_features.fit_transform(x)), color='r',alpha=0.5)
    # plt.show()
PolReg(3)
# Out:
# Degree 3 Testing MSE : 6146112612.531807
# Degree 3 Training MSE : 0.0696863123619302

# %%
PolReg(10)

# %%
df_norm.popularity

X_train['artists'].unique()
# Out:
# array([126, 212, 217, 277, 159, 118, 172, 293, 322, 158,  35,  65,  36,
#         76, 179, 296, 278, 103,  43, 223,  30,  25,  98,  99,  32, 195,
#        171,  53, 258,  16, 167, 160, 242, 146,  89, 234, 152, 260, 143,
#         81,  66, 104, 237, 281,  54, 303, 216,  93, 288, 250, 220, 311,
#        259, 184, 115, 248, 235, 266,  24, 313,  33, 214,  60, 219, 230,
#         29, 320,  37, 254, 196, 310, 116,  64, 333, 317, 332, 155,  11,
#        245, 136, 178, 285, 139, 241,   8, 185, 218, 236,  88, 134,  58,
#         84,  40, 168,  48,  31, 117, 316, 140, 200, 282, 321, 202, 105,
#        331, 232,  42, 176, 111, 161, 323, 215, 308,  21,  83,  27, 108,
#        173, 263, 129, 231, 267,  59, 330, 239, 246, 125,  80, 255, 265,
#          1,  63, 112, 326, 154, 304, 291, 243, 133,  26,  10,  47,  34,
#        244, 204, 287, 252, 306, 166, 138, 325, 141, 193, 286, 269, 148,
#        177, 186, 319, 203,  87, 299,  41, 328, 257,  74, 302, 249, 251,
# ...

# %%
y_train.unique()
# Out:
# array([1, 0, 3, 2])

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

logreg = LogisticRegression()
logreg.fit(X_train,y_train)
yhat_test = logreg.predict(X_test)
logreg.score(X_test, y_test)
print(classification_report(y_test, yhat_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      1.00      0.81       188
#            1       0.67      0.20      0.31        30
#            2       0.00      0.00      0.00        38
#            3       0.00      0.00      0.00        27
#
#     accuracy                           0.69       283
#    macro avg       0.34      0.30      0.28       283
# weighted avg       0.53      0.69      0.57       283
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# ...

# %%
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense
from sklearn.preprocessing import MinMaxScaler

# %%
# Let's initialize our model
model = Sequential() # Initialising the ANN

# %%
# If you decide to initially use a signmoid, make sure the number of units matches the number of targets.
# In this case, we only have 1 target, so for sigmoid, you need to set units to 1.
model.add(Dense(units = 8, activation = 'relu', input_dim = X_train.shape[1]))
model.add(Dense(units = 8, activation = 'relu', input_dim = X_train.shape[1]))
model.add(Dense(units = 8, activation = 'relu', input_dim = X_train.shape[1]))
model.add(Dense(units = 8, activation = 'relu', input_dim = X_train.shape[1]))
model.add(Dense(units = 1, activation = 'sigmoid', input_dim = X_train.shape[1]))

# %%
model.compile(optimizer = 'rmsprop', loss = 'binary_crossentropy')

# %%
model.fit(X_train.astype('float'), y_train, batch_size = 1, epochs = 10)
# Out:
# Epoch 1/10
# 1129/1129 [==============================] - 3s 2ms/step - loss: 1.2720
# Epoch 2/10
# 1129/1129 [==============================] - 3s 2ms/step - loss: 0.4813
# Epoch 3/10
# 1129/1129 [==============================] - 2s 2ms/step - loss: 0.3842
# Epoch 4/10
# 1129/1129 [==============================] - 2s 2ms/step - loss: 0.2490
# Epoch 5/10
# 1129/1129 [==============================] - 2s 2ms/step - loss: 0.2512
# Epoch 6/10
# 1129/1129 [==============================] - 2s 2ms/step - loss: 0.1908
# Epoch 7/10
# 1129/1129 [==============================] - 2s 2ms/step - loss: 0.1892
# Epoch 8/10
# 1129/1129 [==============================] - 2s 2ms/step - loss: 0.1456
# Epoch 9/10
# 1129/1129 [==============================] - 2s 2ms/step - loss: -0.1084
# Epoch 10/10
# 1129/1129 [==============================] - 2s 2ms/step - loss: -0.3362

# %%
yhat_test = model.predict(X_test.astype(float))
#yhat_test
# Out:
# 9/9 [==============================] - 0s 2ms/step

# %%
yhat_test = [ 0 if y<=0.25 else 0 for y in yhat_test ]
y_res = []
for y in yhat_test:
  if y <= 0.25:
    y_res.append(0)
  elif y <= 0.5:
    y_res.append(1)
  elif y <= 0.75:
    y_res.append(2)
  else:
    y_res.append(3)

# %%
from sklearn.metrics import classification_report

# %%
print('Model Classification Report:')
print(classification_report(y_test, y_res))
# Out:
# Model Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.66      1.00      0.80       188
#            1       0.00      0.00      0.00        30
#            2       0.00      0.00      0.00        38
#            3       0.00      0.00      0.00        27
#
#     accuracy                           0.66       283
#    macro avg       0.17      0.25      0.20       283
# weighted avg       0.44      0.66      0.53       283
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...
